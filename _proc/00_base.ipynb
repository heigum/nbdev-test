# %% [raw]
# ---
# description: This module is the walk through of the nbdev onboarding
# output-file: base.html
# title: Base
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# [source](https://github.com/heigum/nbdev-test/blob/main/nbdev_test/base.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hello
#
# >      say_hello (to)
#
# Day hello to sombody

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/heigum/nbdev-test/blob/main/nbdev_test/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(HelloSayer)
# Out:
# ---
#
# [source](https://github.com/heigum/nbdev-test/blob/main/nbdev_test/base.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### HelloSayer
#
# >      HelloSayer (to)
#
# Say hello to `to` using say_hello
